# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import tifffile
import os
from config import *
from model import Click_ref
from dataloader import *
from tqdm import tqdm
from beautifultable import BeautifulTable
from metrics import *
from matching import matching
from skimage.morphology import disk
import neptune.new as neptune
import numpy as np
from scipy.ndimage import gaussian_filter
from skimage.measure import label
from tqdm import trange
from tiloss import Finalloss
from glob import glob
from create_gt_grids import Gtgrid
from grids_to_clicks import Grid_to_click
# Out:
# /home/ahabis/.local/lib/python3.8/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: libtorch_cuda_cu.so: cannot open shared object file: No such file or directory
#   warn(f"Failed to load image Python extension: {e}")
# /tmp/ipykernel_1704773/586032062.py:14: NeptuneDeprecationWarning: You're importing the Neptune client library via the deprecated `neptune.new` module, which will be removed in a future release. Import directly from `neptune` instead.
#   import neptune.new as neptune
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /home/ahabis/1-Click_project/ClickRef/train copy.ipynb Cell 1 line 2
#      <a href='vscode-notebook-cell://ssh-remote%2Bdell1/home/ahabis/1-Click_project/ClickRef/train%20copy.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=18'>19</a> from tiloss import Finalloss
#      <a href='vscode-notebook-cell://ssh-remote%2Bdell1/home/ahabis/1-Click_project/ClickRef/train%20copy.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=19'>20</a> from glob import glob
# ---> <a href='vscode-notebook-cell://ssh-remote%2Bdell1/home/ahabis/1-Click_project/ClickRef/train%20copy.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=20'>21</a> from create_gt_grids import Gtgrid
#      <a href='vscode-notebook-cell://ssh-remote%2Bdell1/home/ahabis/1-Click_project/ClickRef/train%20copy.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=21'>22</a> from grids_to_clicks import Grid_to_click
#
# ModuleNotFoundError: No module named 'create_gt_grids'

# %%
baseline = 'stardist_modified'
path_baseline = os.path.join(path_pannuke, baseline)
path_contour_baseline = os.path.join(path_pannuke, 'contour_'+str(baseline))
path_binary_baseline = os.path.join(path_pannuke, 'binary_'+str(baseline))
path_click_gen_baseline = os.path.join(path_pannuke, 'click_gen_'+str(baseline))
path_click_baseline = os.path.join(path_pannuke, 'click_'+str(baseline))

# %%
click_ref = Click_ref(7,3)
click_ref = click_ref.load_state_dict(torch.load('weights'))

def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)
# count_parameters(click_ref)

# %%
filename = filenames[55]

img_gt = tifffile.imread(os.path.join(path_gt, filename))
img_baseline = tifffile.imread(os.path.join(path_stardist_modified, filename))
grid_creator = Gtgrid(img_gt, img_baseline, area=0)
grid = grid_creator.create_grid()
click_generator = Grid_to_click(grid, filename, path_stardist_modified)
click = click_generator.final_click()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/ahabis/1-Click_project/ClickRef/train.ipynb Cell 4 line 1
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bdell1/home/ahabis/1-Click_project/ClickRef/train.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> filename = filenames[55]
#       <a href='vscode-notebook-cell://ssh-remote%2Bdell1/home/ahabis/1-Click_project/ClickRef/train.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> # click = tifffile.imread(os.path.join(path_click_baseline, filename))
#       <a href='vscode-notebook-cell://ssh-remote%2Bdell1/home/ahabis/1-Click_project/ClickRef/train.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> click_gen = tifffile.imread(os.path.join(path_click_gen_baseline, filename))
#
# NameError: name 'filenames' is not defined

# %%
plt.imshow(img_stardist)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/ahabis/1-Click_project/ClickRef/train.ipynb Cell 5 line 1
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bdell1/home/ahabis/1-Click_project/ClickRef/train.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> plt.imshow(img_stardist)
#       <a href='vscode-notebook-cell://ssh-remote%2Bdell1/home/ahabis/1-Click_project/ClickRef/train.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> plt.show()
#
# NameError: name 'img_stardist' is not defined

# %%
click_ref = Click_ref(7,3)
click_ref.load_state_dict(torch.load('weights'))
click_ref.eval()
# Out:
# Click_ref(
#   (relu): ReLU()
#   (softmax): Softmax(dim=1)
#   (sigmoid): Sigmoid()
#   (conv_corr1): Conv2d(7, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv_corr2): Conv2d_new(
#     (conv): Conv2d(64, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (relu): ReLU()
#   )
#   (conv_corr3): Conv2d_new(
#     (conv): Conv2d(64, 64, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#     (relu): ReLU()
#   )
#   (conv_corr4): Conv2d_new(
#     (conv): Conv2d(64, 64, kernel_size=(9, 9), stride=(1, 1), padding=(4, 4))
#     (relu): ReLU()
#   )
#   (conv_corr5): Conv2d_new(
#     (conv): Conv2d(64, 64, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#     (relu): ReLU()
#   )
#   (conv_corr6): Conv2d_new(
#     (conv): Conv2d(64, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (relu): ReLU()
#   )
#   (conv_corr7): Conv2d(64, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv_prob1): Conv2d(7, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv_prob2): Conv2d_new(
#     (conv): Conv2d(64, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (relu): ReLU()
#   )
#   (conv_prob3): Conv2d_new(
#     (conv): Conv2d(64, 64, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#     (relu): ReLU()
#   )
#   (conv_prob4): Conv2d_new(
#     (conv): Conv2d(64, 64, kernel_size=(9, 9), stride=(1, 1), padding=(4, 4))
#     (relu): ReLU()
#   )
#   (conv_prob5): Conv2d_new(
#     (conv): Conv2d(64, 64, kernel_size=(7, 7), stride=(1, 1), padding=(3, 3))
#     (relu): ReLU()
#   )
#   (conv_prob6): Conv2d_new(
#     (conv): Conv2d(64, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (relu): ReLU()
#   )
#   (conv_prob7): Conv2d(64, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# )

# %%
filename = list(dataloaders["test"].dataset.dataframe["filename"])[41]
click = np.amax(tifffile.imread(os.path.join(path_click_stardist_modified,filename)),-1)
bin_, img_gt= predict_click(filename = filename,
                            model=click_ref,
                            gen=False,
                            baseline = baseline,
                            count_erase= 30)

os.listdir(path_stardist_modified)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# new segmentation
# (0.8666666666666667, 0.7222222222222222, 0.787383231998509, {1: 1, 3: 5, 4: 6, 5: 7, 6: 8, 8: 9, 9: 10, 10: 11, 11: 12, 12: 13, 14: 14, 15: 15, 17: 3})
# stardist
# (0.8, 0.6666666666666666, 0.7267771973654327, {1: 12, 4: 8, 5: 2, 6: 10, 8: 14, 9: 7, 10: 4, 11: 3, 12: 13, 14: 1, 15: 15, 17: 6})
# ['nuclei_2_2470.tif',
#  'nuclei_1_847.tif',
#  'nuclei_3_212.tif',
#  'nuclei_1_1062.tif',
#  'nuclei_1_2409.tif',
#  'nuclei_3_782.tif',
#  'nuclei_1_994.tif',
#  'nuclei_2_1884.tif',
#  'nuclei_3_2328.tif',
#  'nuclei_2_458.tif',
#  'nuclei_1_2259.tif',
#  'nuclei_3_294.tif',
#  'nuclei_2_1662.tif',
#  'nuclei_3_2460.tif',
#  'nuclei_2_490.tif',
#  'nuclei_2_2085.tif',
#  'nuclei_1_666.tif',
#  'nuclei_1_2092.tif',
#  'nuclei_2_334.tif',
#  'nuclei_3_2450.tif',
#  'nuclei_1_744.tif',
#  'nuclei_3_3.tif',
#  'nuclei_3_242.tif',
#  'nuclei_1_99.tif',
#  'nuclei_1_62.tif',
#  'nuclei_3_1562.tif',
#  'nuclei_2_1363.tif',
#  'nuclei_1_200.tif',
#  'nuclei_1_613.tif',
#  'nuclei_1_2337.tif',
#  'nuclei_3_881.tif',
#  'nuclei_1_416.tif',
#  'nuclei_1_2206.tif',
#  'nuclei_3_470.tif',
#  'nuclei_1_751.tif',
#  'nuclei_1_2025.tif',
#  'nuclei_1_1575.tif',
#  'nuclei_3_2223.tif',
#  'nuclei_1_1339.tif',
#  'nuclei_2_2170.tif',
#  'nuclei_3_2019.tif',
#  'nuclei_1_2161.tif',
#  'nuclei_2_2006.tif',
#  'nuclei_1_2387.tif',
#  'nuclei_1_1165.tif',
#  'nuclei_1_2603.tif',
#  'nuclei_3_1179.tif',
#  'nuclei_1_2233.tif',
#  'nuclei_2_772.tif',
#  'nuclei_2_1162.tif',
#  'nuclei_1_1234.tif',
#  'nuclei_2_2223.tif',
#  'nuclei_1_1631.tif',
#  'nuclei_2_1037.tif',
#  'nuclei_1_193.tif',
#  'nuclei_3_1982.tif',
#  'nuclei_1_851.tif',
#  'nuclei_3_2053.tif',
#  'nuclei_1_1057.tif',
#  'nuclei_1_580.tif',
#  'nuclei_2_429.tif',
#  'nuclei_2_1179.tif',
#  'nuclei_3_2092.tif',
#  'nuclei_3_2316.tif',
#  'nuclei_3_911.tif',
#  'nuclei_3_2703.tif',
#  'nuclei_1_175.tif',
#  'nuclei_1_2044.tif',
#  'nuclei_2_455.tif',
#  'nuclei_1_1983.tif',
#  'nuclei_3_174.tif',
#  'nuclei_2_1210.tif',
#  'nuclei_2_1970.tif',
#  'nuclei_1_596.tif',
#  'nuclei_3_1034.tif',
#  'nuclei_1_15.tif',
#  'nuclei_3_1220.tif',
#  'nuclei_1_2455.tif',
#  'nuclei_3_1208.tif',
#  'nuclei_3_351.tif',
#  'nuclei_1_426.tif',
#  'nuclei_1_1929.tif',
#  'nuclei_3_2577.tif',
#  'nuclei_3_1522.tif',
#  'nuclei_1_2187.tif',
#  'nuclei_3_1605.tif',
#  'nuclei_3_1831.tif',
#  'nuclei_1_303.tif',
#  'nuclei_1_1734.tif',
#  'nuclei_1_2062.tif',
#  'nuclei_2_1405.tif',
#  'nuclei_1_668.tif',
#  'nuclei_2_243.tif',
#  'nuclei_2_2283.tif',
#  'nuclei_1_803.tif',
#  'nuclei_2_1630.tif',
#  'nuclei_1_2007.tif',
#  'nuclei_3_845.tif',
#  'nuclei_2_1958.tif',
#  'nuclei_3_542.tif',
#  'nuclei_2_477.tif',
#  'nuclei_2_1465.tif',
#  'nuclei_2_1403.tif',
#  'nuclei_3_2287.tif',
#  'nuclei_3_2293.tif',
#  'nuclei_2_472.tif',
#  'nuclei_3_1386.tif',
#  'nuclei_1_529.tif',
#  'nuclei_1_233.tif',
#  'nuclei_3_575.tif',
#  'nuclei_2_1497.tif',
#  'nuclei_1_1320.tif',
#  'nuclei_3_52.tif',
#  'nuclei_2_1549.tif',
#  'nuclei_3_1512.tif',
#  'nuclei_2_2412.tif',
#  'nuclei_1_811.tif',
#  'nuclei_3_2573.tif',
#  'nuclei_2_155.tif',
#  'nuclei_2_1338.tif',
#  'nuclei_1_2457.tif',
#  'nuclei_3_761.tif',
#  'nuclei_3_488.tif',
#  'nuclei_1_2110.tif',
#  'nuclei_3_2306.tif',
#  'nuclei_1_2580.tif',
#  'nuclei_1_276.tif',
#  'nuclei_1_1086.tif',
#  'nuclei_2_986.tif',
#  'nuclei_1_1805.tif',
#  'nuclei_2_1389.tif',
#  'nuclei_3_1988.tif',
#  'nuclei_1_448.tif',
#  'nuclei_1_2421.tif',
#  'nuclei_1_2446.tif',
#  'nuclei_3_1287.tif',
#  'nuclei_1_1622.tif',
#  'nuclei_3_127.tif',
#  'nuclei_1_1999.tif',
#  'nuclei_3_2631.tif',
#  'nuclei_3_198.tif',
#  'nuclei_2_2128.tif',
#  'nuclei_1_2312.tif',
#  'nuclei_3_1669.tif',
#  'nuclei_3_494.tif',
#  'nuclei_3_1355.tif',
#  'nuclei_3_148.tif',
#  'nuclei_3_875.tif',
#  'nuclei_2_1112.tif',
#  'nuclei_1_129.tif',
#  'nuclei_2_228.tif',
#  'nuclei_1_1519.tif',
#  'nuclei_2_1095.tif',
#  'nuclei_1_866.tif',
#  'nuclei_2_544.tif',
#  'nuclei_3_1944.tif',
#  'nuclei_1_70.tif',
#  'nuclei_1_670.tif',
#  'nuclei_1_1318.tif',
#  'nuclei_3_1046.tif',
#  'nuclei_1_1815.tif',
#  'nuclei_3_292.tif',
#  'nuclei_2_1023.tif',
#  'nuclei_2_1528.tif',
#  'nuclei_3_1601.tif',
#  'nuclei_3_1241.tif',
#  'nuclei_3_1479.tif',
#  'nuclei_2_1115.tif',
#  'nuclei_1_855.tif',
#  'nuclei_1_707.tif',
#  'nuclei_3_128.tif',
#  'nuclei_3_1190.tif',
#  'nuclei_2_1867.tif',
#  'nuclei_2_2105.tif',
#  'nuclei_2_1251.tif',
#  'nuclei_3_598.tif',
#  'nuclei_3_289.tif',
#  'nuclei_1_1394.tif',
#  'nuclei_3_1176.tif',
#  'nuclei_2_2075.tif',
#  'nuclei_3_1603.tif',
#  'nuclei_3_2184.tif',
#  'nuclei_3_2187.tif',
#  'nuclei_2_1775.tif',
#  'nuclei_2_946.tif',
#  'nuclei_2_1693.tif',
#  'nuclei_3_193.tif',
#  'nuclei_1_425.tif',
#  'nuclei_1_612.tif',
#  'nuclei_1_2041.tif',
#  'nuclei_1_91.tif',
#  'nuclei_3_1068.tif',
#  'nuclei_3_565.tif',
#  'nuclei_2_1857.tif',
#  'nuclei_1_1150.tif',
#  'nuclei_3_1570.tif',
#  'nuclei_3_1197.tif',
#  'nuclei_1_1359.tif',
#  'nuclei_1_2527.tif',
#  'nuclei_3_645.tif',
#  'nuclei_1_1577.tif',
#  'nuclei_3_385.tif',
#  'nuclei_3_1920.tif',
#  'nuclei_3_2575.tif',
#  'nuclei_3_1652.tif',
#  'nuclei_2_2457.tif',
#  'nuclei_2_319.tif',
#  'nuclei_1_2649.tif',
#  'nuclei_1_2251.tif',
#  'nuclei_1_1153.tif',
#  'nuclei_2_2406.tif',
#  'nuclei_2_2038.tif',
#  'nuclei_1_1993.tif',
#  'nuclei_1_1366.tif',
#  'nuclei_1_1010.tif',
#  'nuclei_3_284.tif',
#  'nuclei_3_1809.tif',
#  'nuclei_3_1588.tif',
#  'nuclei_2_1348.tif',
#  'nuclei_2_988.tif',
#  'nuclei_2_314.tif',
#  'nuclei_1_1459.tif',
#  'nuclei_1_513.tif',
#  'nuclei_3_2645.tif',
#  'nuclei_2_189.tif',
#  'nuclei_2_2342.tif',
#  'nuclei_1_681.tif',
#  'nuclei_3_506.tif',
#  'nuclei_2_767.tif',
#  'nuclei_3_1682.tif',
#  'nuclei_2_1975.tif',
#  'nuclei_1_1473.tif',
#  'nuclei_2_1247.tif',
#  'nuclei_1_1551.tif',
#  'nuclei_3_1181.tif',
#  'nuclei_2_861.tif',
#  'nuclei_1_81.tif',
#  'nuclei_2_566.tif',
#  'nuclei_3_2112.tif',
#  'nuclei_3_1664.tif',
#  'nuclei_3_317.tif',
#  'nuclei_1_2097.tif',
#  'nuclei_3_214.tif',
#  'nuclei_2_2255.tif',
#  'nuclei_3_2258.tif',
#  'nuclei_2_1980.tif',
#  'nuclei_3_1532.tif',
#  'nuclei_1_737.tif',
#  'nuclei_2_800.tif',
#  'nuclei_2_582.tif',
#  'nuclei_2_1347.tif',
#  'nuclei_2_1874.tif',
#  'nuclei_3_1297.tif',
#  'nuclei_3_1251.tif',
#  'nuclei_2_2150.tif',
#  'nuclei_2_1034.tif',
#  'nuclei_3_1286.tif',
#  'nuclei_2_1006.tif',
#  'nuclei_1_1518.tif',
#  'nuclei_1_1245.tif',
#  'nuclei_1_359.tif',
#  'nuclei_1_493.tif',
#  'nuclei_3_1904.tif',
#  'nuclei_1_2546.tif',
#  'nuclei_3_2618.tif',
#  'nuclei_2_1579.tif',
#  'nuclei_1_2475.tif',
#  'nuclei_2_2180.tif',
#  'nuclei_3_200.tif',
#  'nuclei_2_1772.tif',
#  'nuclei_3_0.tif',
#  'nuclei_3_490.tif',
#  'nuclei_2_2019.tif',
#  'nuclei_2_752.tif',
#  'nuclei_1_609.tif',
#  'nuclei_1_2013.tif',
#  'nuclei_3_1684.tif',
#  'nuclei_3_520.tif',
#  'nuclei_1_828.tif',
#  'nuclei_1_13.tif',
#  'nuclei_3_1705.tif',
#  'nuclei_1_371.tif',
#  'nuclei_3_802.tif',
#  'nuclei_3_2078.tif',
#  'nuclei_3_320.tif',
#  'nuclei_3_2507.tif',
#  'nuclei_2_24.tif',
#  'nuclei_3_329.tif',
#  'nuclei_1_2100.tif',
#  'nuclei_3_322.tif',
#  'nuclei_2_1342.tif',
#  'nuclei_3_514.tif',
#  'nuclei_1_568.tif',
#  'nuclei_2_336.tif',
#  'nuclei_2_825.tif',
#  'nuclei_1_2245.tif',
#  'nuclei_3_2475.tif',
#  'nuclei_1_1405.tif',
#  'nuclei_2_1203.tif',
#  'nuclei_1_1105.tif',
#  'nuclei_1_2478.tif',
#  'nuclei_3_1394.tif',
#  'nuclei_3_499.tif',
#  'nuclei_1_1847.tif',
#  'nuclei_1_864.tif',
#  'nuclei_3_2116.tif',
#  'nuclei_1_1323.tif',
#  'nuclei_2_2041.tif',
#  'nuclei_3_2415.tif',
#  'nuclei_3_785.tif',
#  'nuclei_3_1448.tif',
#  'nuclei_3_1616.tif',
#  'nuclei_1_2382.tif',
#  'nuclei_2_1297.tif',
#  'nuclei_1_971.tif',
#  'nuclei_1_1112.tif',
#  'nuclei_1_699.tif',
#  'nuclei_1_2194.tif',
#  'nuclei_2_1220.tif',
#  'nuclei_2_673.tif',
#  'nuclei_1_1230.tif',
#  'nuclei_2_2444.tif',
#  'nuclei_1_2158.tif',
#  'nuclei_3_1721.tif',
#  'nuclei_2_1475.tif',
#  'nuclei_2_1434.tif',
#  'nuclei_1_1759.tif',
#  'nuclei_3_1824.tif',
#  'nuclei_3_2248.tif',
#  'nuclei_1_1864.tif',
#  'nuclei_1_2523.tif',
#  'nuclei_3_2202.tif',
#  'nuclei_2_70.tif',
#  'nuclei_3_863.tif',
#  'nuclei_1_394.tif',
#  'nuclei_2_1721.tif',
#  'nuclei_3_1560.tif',
#  'nuclei_2_447.tif',
#  'nuclei_2_55.tif',
#  'nuclei_2_1325.tif',
#  'nuclei_1_284.tif',
#  'nuclei_3_600.tif',
#  'nuclei_2_2513.tif',
#  'nuclei_3_2197.tif',
#  'nuclei_3_1255.tif',
#  'nuclei_3_2188.tif',
#  'nuclei_2_643.tif',
#  'nuclei_1_1467.tif',
#  'nuclei_1_1315.tif',
#  'nuclei_3_553.tif',
#  'nuclei_1_2023.tif',
#  'nuclei_1_1846.tif',
#  'nuclei_1_93.tif',
#  'nuclei_2_2316.tif',
#  'nuclei_2_1800.tif',
#  'nuclei_3_601.tif',
#  'nuclei_1_1768.tif',
#  'nuclei_3_546.tif',
#  'nuclei_2_1142.tif',
#  'nuclei_2_1812.tif',
#  'nuclei_3_1170.tif',
#  'nuclei_2_330.tif',
#  'nuclei_2_2218.tif',
#  'nuclei_2_906.tif',
#  'nuclei_2_1515.tif',
#  'nuclei_2_1882.tif',
#  'nuclei_3_168.tif',
#  'nuclei_2_2471.tif',
#  'nuclei_1_435.tif',
#  'nuclei_2_716.tif',
#  'nuclei_2_2451.tif',
#  'nuclei_1_1065.tif',
#  'nuclei_1_1266.tif',
#  'nuclei_2_1189.tif',
#  'nuclei_3_1541.tif',
#  'nuclei_1_1555.tif',
#  'nuclei_1_1322.tif',
#  'nuclei_3_574.tif',
#  'nuclei_3_2363.tif',
#  'nuclei_3_810.tif',
#  'nuclei_2_651.tif',
#  'nuclei_1_686.tif',
#  'nuclei_3_971.tif',
#  'nuclei_1_607.tif',
#  'nuclei_2_916.tif',
#  'nuclei_2_1450.tif',
#  'nuclei_1_1671.tif',
#  'nuclei_2_934.tif',
#  'nuclei_1_1910.tif',
#  'nuclei_2_594.tif',
#  'nuclei_1_534.tif',
#  'nuclei_1_2165.tif',
#  'nuclei_3_913.tif',
#  'nuclei_1_16.tif',
#  'nuclei_2_987.tif',
#  'nuclei_2_1177.tif',
#  'nuclei_1_286.tif',
#  'nuclei_1_429.tif',
#  'nuclei_2_2337.tif',
#  'nuclei_3_1389.tif',
#  'nuclei_3_2505.tif',
#  'nuclei_1_1743.tif',
#  'nuclei_3_372.tif',
#  'nuclei_1_2552.tif',
#  'nuclei_1_1901.tif',
#  'nuclei_2_93.tif',
#  'nuclei_1_1187.tif',
#  'nuclei_1_2049.tif',
#  'nuclei_3_1315.tif',
#  'nuclei_3_1788.tif',
#  'nuclei_3_2047.tif',
#  'nuclei_3_2108.tif',
#  'nuclei_1_997.tif',
#  'nuclei_3_1057.tif',
#  'nuclei_3_65.tif',
#  'nuclei_1_1899.tif',
#  'nuclei_2_591.tif',
#  'nuclei_2_1291.tif',
#  'nuclei_3_1285.tif',
#  'nuclei_2_1709.tif',
#  'nuclei_1_1308.tif',
#  'nuclei_1_1795.tif',
#  'nuclei_2_915.tif',
#  'nuclei_1_2467.tif',
#  'nuclei_2_434.tif',
#  'nuclei_3_2012.tif',
#  'nuclei_3_908.tif',
#  'nuclei_1_2450.tif',
#  'nuclei_3_2374.tif',
#  'nuclei_2_1510.tif',
#  'nuclei_3_2331.tif',
#  'nuclei_1_1591.tif',
#  'nuclei_3_1353.tif',
#  'nuclei_2_1758.tif',
#  'nuclei_3_81.tif',
#  'nuclei_2_865.tif',
#  'nuclei_3_343.tif',
#  'nuclei_3_1472.tif',
#  'nuclei_3_1192.tif',
#  'nuclei_3_2606.tif',
#  'nuclei_1_1142.tif',
#  'nuclei_3_2542.tif',
#  'nuclei_2_509.tif',
#  'nuclei_3_1321.tif',
#  'nuclei_1_218.tif',
#  'nuclei_2_2473.tif',
#  'nuclei_1_1034.tif',
#  'nuclei_1_1088.tif',
#  'nuclei_1_2093.tif',
#  'nuclei_2_2289.tif',
#  'nuclei_3_227.tif',
#  'nuclei_1_1896.tif',
#  'nuclei_3_720.tif',
#  'nuclei_1_948.tif',
#  'nuclei_1_1195.tif',
#  'nuclei_3_1234.tif',
#  'nuclei_1_1945.tif',
#  'nuclei_1_50.tif',
#  'nuclei_3_739.tif',
#  'nuclei_1_2066.tif',
#  'nuclei_1_1487.tif',
#  'nuclei_2_1314.tif',
#  'nuclei_3_789.tif',
#  'nuclei_2_2215.tif',
#  'nuclei_1_1472.tif',
#  'nuclei_1_1436.tif',
#  'nuclei_2_2175.tif',
#  'nuclei_3_1874.tif',
#  'nuclei_3_2270.tif',
#  'nuclei_1_1998.tif',
#  'nuclei_3_2144.tif',
#  'nuclei_2_634.tif',
#  'nuclei_3_2001.tif',
#  'nuclei_1_1260.tif',
#  'nuclei_3_140.tif',
#  'nuclei_1_23.tif',
#  'nuclei_3_1607.tif',
#  'nuclei_3_1360.tif',
#  'nuclei_1_2156.tif',
#  'nuclei_1_2573.tif',
#  'nuclei_2_886.tif',
#  'nuclei_1_517.tif',
#  'nuclei_3_1050.tif',
#  'nuclei_1_2236.tif',
#  'nuclei_1_413.tif',
#  'nuclei_2_728.tif',
#  'nuclei_1_1843.tif',
#  'nuclei_2_1424.tif',
#  'nuclei_3_1099.tif',
#  'nuclei_2_110.tif',
#  'nuclei_1_540.tif',
#  'nuclei_1_1363.tif',
#  'nuclei_2_2181.tif',
#  'nuclei_2_1158.tif',
#  'nuclei_1_2300.tif',
#  'nuclei_3_1678.tif',
#  'nuclei_2_952.tif',
#  'nuclei_3_879.tif',
#  'nuclei_1_1401.tif',
#  'nuclei_2_1964.tif',
#  'nuclei_3_1953.tif',
#  'nuclei_2_819.tif',
#  'nuclei_3_698.tif',
#  'nuclei_1_2019.tif',
#  'nuclei_1_574.tif',
#  'nuclei_2_463.tif',
#  'nuclei_1_2645.tif',
#  'nuclei_1_1125.tif',
#  'nuclei_1_1186.tif',
#  'nuclei_1_1488.tif',
#  'nuclei_2_876.tif',
#  'nuclei_1_1790.tif',
#  'nuclei_2_786.tif',
#  'nuclei_1_1705.tif',
#  'nuclei_3_885.tif',
#  'nuclei_1_729.tif',
#  'nuclei_1_38.tif',
#  'nuclei_2_1196.tif',
#  'nuclei_1_22.tif',
#  'nuclei_2_500.tif',
#  'nuclei_1_1567.tif',
#  'nuclei_3_1324.tif',
#  'nuclei_2_893.tif',
#  'nuclei_1_894.tif',
#  'nuclei_3_31.tif',
#  'nuclei_3_2291.tif',
#  'nuclei_3_1579.tif',
#  'nuclei_1_1840.tif',
#  'nuclei_2_2115.tif',
#  'nuclei_1_142.tif',
#  'nuclei_1_722.tif',
#  'nuclei_3_935.tif',
#  'nuclei_2_1455.tif',
#  'nuclei_2_2483.tif',
#  'nuclei_1_1216.tif',
#  'nuclei_2_2136.tif',
#  'nuclei_2_606.tif',
#  'nuclei_1_2494.tif',
#  'nuclei_1_2554.tif',
#  'nuclei_3_2467.tif',
#  'nuclei_1_2639.tif',
#  'nuclei_3_846.tif',
#  'nuclei_3_2128.tif',
#  'nuclei_1_1155.tif',
#  'nuclei_1_2648.tif',
#  'nuclei_3_829.tif',
#  'nuclei_1_2230.tif',
#  'nuclei_1_1940.tif',
#  'nuclei_3_1755.tif',
#  'nuclei_1_1029.tif',
#  'nuclei_3_1626.tif',
#  'nuclei_3_2349.tif',
#  'nuclei_2_2369.tif',
#  'nuclei_1_1306.tif',
#  'nuclei_2_1171.tif',
#  'nuclei_2_2498.tif',
#  'nuclei_2_1064.tif',
#  'nuclei_2_1944.tif',
#  'nuclei_1_1218.tif',
#  'nuclei_1_504.tif',
#  'nuclei_1_343.tif',
#  'nuclei_3_809.tif',
#  'nuclei_2_68.tif',
#  'nuclei_2_1580.tif',
#  'nuclei_3_2280.tif',
#  'nuclei_3_537.tif',
#  'nuclei_1_1036.tif',
#  'nuclei_2_2321.tif',
#  'nuclei_1_125.tif',
#  'nuclei_1_2078.tif',
#  'nuclei_3_126.tif',
#  'nuclei_1_1343.tif',
#  'nuclei_1_1637.tif',
#  'nuclei_3_1134.tif',
#  'nuclei_3_2044.tif',
#  'nuclei_3_1821.tif',
#  'nuclei_3_733.tif',
#  'nuclei_1_1681.tif',
#  'nuclei_3_262.tif',
#  'nuclei_1_1179.tif',
#  'nuclei_2_1610.tif',
#  'nuclei_2_1845.tif',
#  'nuclei_3_2132.tif',
#  'nuclei_3_2392.tif',
#  'nuclei_1_2600.tif',
#  'nuclei_3_114.tif',
#  'nuclei_3_478.tif',
#  'nuclei_3_2581.tif',
#  'nuclei_2_126.tif',
#  'nuclei_3_675.tif',
#  'nuclei_2_1915.tif',
#  'nuclei_1_350.tif',
#  'nuclei_2_2281.tif',
#  'nuclei_2_957.tif',
#  'nuclei_3_2381.tif',
#  'nuclei_3_1455.tif',
#  'nuclei_2_2441.tif',
#  'nuclei_2_2178.tif',
#  'nuclei_1_1736.tif',
#  'nuclei_1_2140.tif',
#  'nuclei_3_28.tif',
#  'nuclei_1_2390.tif',
#  'nuclei_3_274.tif',
#  'nuclei_1_2149.tif',
#  'nuclei_3_2225.tif',
#  'nuclei_1_2609.tif',
#  'nuclei_1_1702.tif',
#  'nuclei_1_640.tif',
#  'nuclei_3_176.tif',
#  'nuclei_1_2192.tif',
#  'nuclei_1_2163.tif',
#  'nuclei_1_1950.tif',
#  'nuclei_2_2025.tif',
#  'nuclei_3_2670.tif',
#  'nuclei_2_1953.tif',
#  'nuclei_2_1309.tif',
#  'nuclei_2_407.tif',
#  'nuclei_1_1714.tif',
#  'nuclei_2_1955.tif',
#  'nuclei_1_2010.tif',
#  'nuclei_1_1676.tif',
#  'nuclei_3_2533.tif',
#  'nuclei_3_2156.tif',
#  'nuclei_3_1787.tif',
#  'nuclei_2_315.tif',
#  'nuclei_1_1656.tif',
#  'nuclei_1_0.tif',
#  'nuclei_3_1861.tif',
#  'nuclei_2_52.tif',
#  'nuclei_1_2505.tif',
#  'nuclei_1_489.tif',
#  'nuclei_3_1368.tif',
#  'nuclei_3_1253.tif',
#  'nuclei_3_1087.tif',
#  'nuclei_2_1559.tif',
#  'nuclei_2_670.tif',
#  'nuclei_2_1582.tif',
#  'nuclei_3_1505.tif',
#  'nuclei_2_199.tif',
#  'nuclei_3_363.tif',
#  'nuclei_3_1344.tif',
#  'nuclei_1_2185.tif',
#  'nuclei_1_2083.tif',
#  'nuclei_2_227.tif',
#  'nuclei_3_1393.tif',
#  'nuclei_2_1231.tif',
#  'nuclei_3_1073.tif',
#  'nuclei_3_1247.tif',
#  'nuclei_3_1924.tif',
#  'nuclei_2_626.tif',
#  'nuclei_1_618.tif',
#  'nuclei_1_1291.tif',
#  'nuclei_1_1784.tif',
#  'nuclei_1_1261.tif',
#  'nuclei_3_2266.tif',
#  'nuclei_1_2229.tif',
#  'nuclei_1_1082.tif',
#  'nuclei_1_1146.tif',
#  'nuclei_1_880.tif',
#  'nuclei_2_2515.tif',
#  'nuclei_3_2681.tif',
#  'nuclei_2_981.tif',
#  'nuclei_1_523.tif',
#  'nuclei_3_1089.tif',
#  'nuclei_1_2210.tif',
#  'nuclei_1_113.tif',
#  'nuclei_3_2288.tif',
#  'nuclei_1_2431.tif',
#  'nuclei_1_905.tif',
#  'nuclei_1_672.tif',
#  'nuclei_2_692.tif',
#  'nuclei_1_798.tif',
#  'nuclei_2_1167.tif',
#  'nuclei_1_2138.tif',
#  'nuclei_1_1897.tif',
#  'nuclei_1_305.tif',
#  'nuclei_2_864.tif',
#  'nuclei_1_2129.tif',
#  'nuclei_2_2449.tif',
#  'nuclei_1_1615.tif',
#  'nuclei_3_2648.tif',
#  'nuclei_3_1171.tif',
#  'nuclei_3_2143.tif',
#  'nuclei_1_292.tif',
#  'nuclei_1_2278.tif',
#  'nuclei_2_1712.tif',
#  'nuclei_1_357.tif',
#  'nuclei_2_1934.tif',
#  'nuclei_2_596.tif',
#  'nuclei_2_601.tif',
#  'nuclei_2_2221.tif',
#  'nuclei_1_1866.tif',
#  'nuclei_1_2517.tif',
#  'nuclei_1_2570.tif',
#  'nuclei_1_2291.tif',
#  'nuclei_1_1407.tif',
#  'nuclei_2_1606.tif',
#  'nuclei_1_1633.tif',
#  'nuclei_1_1312.tif',
#  'nuclei_3_1215.tif',
#  'nuclei_2_1796.tif',
#  'nuclei_2_1593.tif',
#  'nuclei_1_1314.tif',
#  'nuclei_1_384.tif',
#  'nuclei_3_302.tif',
#  'nuclei_3_1848.tif',
#  'nuclei_1_2340.tif',
#  'nuclei_2_1066.tif',
#  'nuclei_2_394.tif',
#  'nuclei_3_1459.tif',
#  'nuclei_3_235.tif',
#  'nuclei_2_414.tif',
#  'nuclei_3_770.tif',
#  'nuclei_2_646.tif',
#  'nuclei_3_2641.tif',
#  'nuclei_1_1894.tif',
#  'nuclei_2_495.tif',
#  'nuclei_3_508.tif',
#  'nuclei_1_671.tif',
#  'nuclei_2_1242.tif',
#  'nuclei_2_835.tif',
#  'nuclei_2_1634.tif',
#  'nuclei_3_2536.tif',
#  'nuclei_2_150.tif',
#  'nuclei_3_1794.tif',
#  'nuclei_3_1611.tif',
#  'nuclei_2_1939.tif',
#  'nuclei_3_252.tif',
#  'nuclei_2_1056.tif',
#  'nuclei_1_497.tif',
#  'nuclei_1_445.tif',
#  'nuclei_1_1448.tif',
#  'nuclei_1_527.tif',
#  'nuclei_3_610.tif',
#  'nuclei_3_221.tif',
#  'nuclei_3_328.tif',
#  'nuclei_3_1957.tif',
#  'nuclei_2_2039.tif',
#  'nuclei_1_2052.tif',
#  'nuclei_2_1555.tif',
#  'nuclei_1_1741.tif',
#  'nuclei_2_1151.tif',
#  'nuclei_1_1466.tif',
#  'nuclei_2_140.tif',
#  'nuclei_3_1064.tif',
#  'nuclei_1_706.tif',
#  'nuclei_2_569.tif',
#  'nuclei_2_484.tif',
#  'nuclei_3_1545.tif',
#  'nuclei_1_1600.tif',
#  'nuclei_1_295.tif',
#  'nuclei_1_1148.tif',
#  'nuclei_1_1003.tif',
#  'nuclei_3_869.tif',
#  'nuclei_1_676.tif',
#  'nuclei_3_2220.tif',
#  'nuclei_1_2432.tif',
#  'nuclei_2_264.tif',
#  'nuclei_3_2487.tif',
#  'nuclei_1_1602.tif',
#  'nuclei_3_2183.tif',
#  'nuclei_2_1233.tif',
#  'nuclei_3_684.tif',
#  'nuclei_3_1662.tif',
#  'nuclei_2_2474.tif',
#  'nuclei_1_2126.tif',
#  'nuclei_2_542.tif',
#  'nuclei_1_749.tif',
#  'nuclei_3_1027.tif',
#  'nuclei_1_933.tif',
#  'nuclei_1_1045.tif',
#  'nuclei_2_2140.tif',
#  'nuclei_2_1517.tif',
#  'nuclei_3_2655.tif',
#  'nuclei_2_196.tif',
#  'nuclei_3_2005.tif',
#  'nuclei_1_2451.tif',
#  'nuclei_1_748.tif',
#  'nuclei_3_1926.tif',
#  'nuclei_1_1301.tif',
#  'nuclei_3_784.tif',
#  'nuclei_3_747.tif',
#  'nuclei_2_357.tif',
#  'nuclei_2_1966.tif',
#  'nuclei_1_1041.tif',
#  'nuclei_3_511.tif',
#  'nuclei_3_1806.tif',
#  'nuclei_3_326.tif',
#  'nuclei_3_1169.tif',
#  'nuclei_2_2480.tif',
#  'nuclei_1_2577.tif',
#  'nuclei_2_327.tif',
#  'nuclei_3_1407.tif',
#  'nuclei_2_1019.tif',
#  'nuclei_3_2662.tif',
#  'nuclei_3_92.tif',
#  'nuclei_3_1499.tif',
#  'nuclei_1_2056.tif',
#  'nuclei_3_2501.tif',
#  'nuclei_2_1514.tif',
#  'nuclei_2_905.tif',
#  'nuclei_1_1538.tif',
#  'nuclei_1_1780.tif',
#  'nuclei_1_610.tif',
#  'nuclei_3_2398.tif',
#  'nuclei_2_1950.tif',
#  'nuclei_2_2435.tif',
#  'nuclei_2_1625.tif',
#  'nuclei_1_2157.tif',
#  'nuclei_1_2628.tif',
#  'nuclei_1_2433.tif',
#  'nuclei_2_1152.tif',
#  'nuclei_3_394.tif',
#  'nuclei_3_392.tif',
#  'nuclei_1_956.tif',
#  'nuclei_1_2525.tif',
#  'nuclei_2_69.tif',
#  'nuclei_2_639.tif',
#  'nuclei_3_1508.tif',
#  'nuclei_1_2069.tif',
#  'nuclei_1_1873.tif',
#  'nuclei_1_727.tif',
#  'nuclei_1_456.tif',
#  'nuclei_2_435.tif',
#  'nuclei_2_410.tif',
#  'nuclei_3_1091.tif',
#  'nuclei_1_2458.tif',
#  'nuclei_1_2055.tif',
#  'nuclei_3_2658.tif',
#  'nuclei_3_2284.tif',
#  'nuclei_3_910.tif',
#  'nuclei_2_637.tif',
#  'nuclei_2_575.tif',
#  'nuclei_1_1643.tif',
#  'nuclei_2_282.tif',
#  'nuclei_1_1326.tif',
#  'nuclei_2_1694.tif',
#  'nuclei_1_746.tif',
#  'nuclei_3_1147.tif',
#  'nuclei_2_942.tif',
#  'nuclei_3_2056.tif',
#  'nuclei_2_1128.tif',
#  'nuclei_3_486.tif',
#  'nuclei_2_2343.tif',
#  'nuclei_2_1308.tif',
#  'nuclei_3_1887.tif',
#  'nuclei_2_2512.tif',
#  'nuclei_1_1042.tif',
#  'nuclei_3_1174.tif',
#  'nuclei_2_507.tif',
#  'nuclei_2_168.tif',
#  'nuclei_2_1454.tif',
#  'nuclei_2_2434.tif',
#  'nuclei_1_1738.tif',
#  'nuclei_2_1080.tif',
#  'nuclei_1_608.tif',
#  'nuclei_2_58.tif',
#  'nuclei_3_1837.tif',
#  'nuclei_2_1183.tif',
#  'nuclei_3_612.tif',
#  'nuclei_1_1574.tif',
#  'nuclei_2_1306.tif',
#  'nuclei_1_2322.tif',
#  'nuclei_1_1464.tif',
#  'nuclei_2_588.tif',
#  'nuclei_3_414.tif',
#  'nuclei_1_2209.tif',
#  'nuclei_1_1370.tif',
#  'nuclei_1_160.tif',
#  'nuclei_3_2656.tif',
#  'nuclei_1_190.tif',
#  'nuclei_3_2653.tif',
#  'nuclei_1_428.tif',
#  'nuclei_3_2719.tif',
#  'nuclei_3_2378.tif',
#  'nuclei_1_1585.tif',
#  'nuclei_2_681.tif',
#  'nuclei_1_1966.tif',
#  'nuclei_1_1858.tif',
#  'nuclei_2_1918.tif',
#  'nuclei_1_168.tif',
#  'nuclei_3_2084.tif',
#  'nuclei_2_1249.tif',
#  'nuclei_3_2595.tif',
#  'nuclei_1_823.tif',
#  'nuclei_2_1030.tif',
#  'nuclei_1_1109.tif',
#  'nuclei_2_1933.tif',
#  'nuclei_3_956.tif',
#  'nuclei_2_2518.tif',
#  'nuclei_2_1326.tif',
#  'nuclei_1_2076.tif',
#  'nuclei_1_2319.tif',
#  'nuclei_2_1069.tif',
#  'nuclei_3_2343.tif',
#  'nuclei_1_2077.tif',
#  'nuclei_1_800.tif',
#  'nuclei_3_2239.tif',
#  'nuclei_1_1025.tif',
#  'nuclei_1_128.tif',
#  'nuclei_1_1919.tif',
#  'nuclei_3_469.tif',
#  'nuclei_2_1878.tif',
#  'nuclei_2_969.tif',
#  'nuclei_1_766.tif',
#  'nuclei_3_1271.tif',
#  'nuclei_1_726.tif',
#  'nuclei_2_678.tif',
#  'nuclei_1_944.tif',
#  'nuclei_3_1895.tif',
#  'nuclei_2_28.tif',
#  'nuclei_1_313.tif',
#  'nuclei_1_274.tif',
#  'nuclei_2_1814.tif',
#  'nuclei_2_699.tif',
#  'nuclei_2_980.tif',
#  'nuclei_2_1529.tif',
#  'nuclei_3_1668.tif',
#  'nuclei_2_1075.tif',
#  'nuclei_2_610.tif',
#  'nuclei_1_1106.tif',
#  'nuclei_1_1484.tif',
#  'nuclei_2_1672.tif',
#  'nuclei_2_1666.tif',
#  'nuclei_1_1923.tif',
#  'nuclei_3_2626.tif',
#  'nuclei_1_1224.tif',
#  'nuclei_3_1209.tif',
#  'nuclei_1_552.tif',
#  'nuclei_3_1059.tif',
#  'nuclei_3_474.tif',
#  'nuclei_2_384.tif',
#  'nuclei_1_2424.tif',
#  'nuclei_3_1691.tif',
#  'nuclei_1_1128.tif',
#  'nuclei_1_2637.tif',
#  'nuclei_3_1382.tif',
#  'nuclei_2_2414.tif',
#  'nuclei_3_314.tif',
#  'nuclei_2_873.tif',
#  'nuclei_1_2419.tif',
#  'nuclei_1_232.tif',
#  'nuclei_1_167.tif',
#  'nuclei_3_1483.tif',
#  'nuclei_3_1441.tif',
#  'nuclei_2_16.tif',
#  'nuclei_2_2366.tif',
#  'nuclei_3_97.tif',
#  'nuclei_1_2216.tif',
#  'nuclei_3_1268.tif',
#  'nuclei_2_1449.tif',
#  'nuclei_3_1100.tif',
#  'nuclei_2_2257.tif',
#  'nuclei_2_1329.tif',
#  'nuclei_1_1059.tif',
#  'nuclei_2_419.tif',
#  'nuclei_1_820.tif',
#  'nuclei_3_1786.tif',
#  'nuclei_3_132.tif',
#  'nuclei_1_2471.tif',
#  'nuclei_1_1213.tif',
#  'nuclei_2_1320.tif',
#  'nuclei_2_867.tif',
#  'nuclei_2_235.tif',
#  'nuclei_3_1649.tif',
#  'nuclei_2_724.tif',
#  'nuclei_1_1118.tif',
#  'nuclei_3_2104.tif',
#  'nuclei_2_2189.tif',
#  'nuclei_2_370.tif',
#  'nuclei_3_878.tif',
#  'nuclei_1_338.tif',
#  'nuclei_3_792.tif',
#  'nuclei_3_115.tif',
#  'nuclei_2_2401.tif',
#  'nuclei_3_1494.tif',
#  'nuclei_3_791.tif',
#  'nuclei_2_1604.tif',
#  'nuclei_2_1188.tif',
#  'nuclei_1_1996.tif',
#  'nuclei_3_1703.tif',
#  'nuclei_2_2485.tif',
#  'nuclei_3_2387.tif',
#  'nuclei_1_1302.tif',
#  'nuclei_1_812.tif',
#  'nuclei_3_507.tif',
#  'nuclei_1_1668.tif',
#  'nuclei_2_1380.tif',
#  'nuclei_3_161.tif',
#  'nuclei_2_2100.tif',
#  'nuclei_2_1509.tif',
#  'nuclei_3_404.tif',
#  'nuclei_1_2200.tif',
#  'nuclei_3_2259.tif',
#  'nuclei_3_365.tif',
#  'nuclei_1_641.tif',
#  'nuclei_2_411.tif',
#  'nuclei_1_1451.tif',
#  'nuclei_1_1093.tif',
#  'nuclei_1_330.tif',
#  ...]

# %%
dataset_test = CustomImageDataset(path_contour_baseline =path_contour_baseline,
                                   path_baseline = path_baseline,
                                   path_click_gen = path_click_baseline,
                                   path_click = path_click_baseline,
                                   path_image = path_images,
                                   path_contour_gt = path_contour_gt,
                                   path_gt = path_gt,
                                   dataframe = df_test,
                                   augmenter_bool = False)


loader_test = DataLoader(
    batch_size = parameters['batch_size'],
    dataset = dataset_test,
    num_workers = 16,
    shuffle = False)

# %%
list_preds = []
list_filenames = []

with torch.no_grad():
    
    for batch in tqdm(loader_test):
        
        images    = batch[0].cuda()
        stardists    = batch[1].cuda()
        outputs    = batch[2].cuda()

        pred_outputs = click_ref(images, stardists)
        list_preds.append(pred_outputs)
        
preds = np.transpose(torch.cat(list_preds).reshape(-1,3,256,256).cpu().detach().numpy(),(0,2,3,1))
# Out:
# 100%|██████████| 38/38 [00:18<00:00,  2.11it/s]

# %%
star_P, star_R, star_F1, star_pan,star_AJI,star_DICE = [] ,[], [], [], [], []
new_P, new_R, new_F1, new_pan,new_AJI,new_DICE = [], [], [], [], [], []
t = trange(preds.shape[0])


for i in t:
        filename = list(loader_test.dataset.dataframe['filename'])[i]
        click = tifffile.imread(os.path.join(path_click_gen_baseline, filename))
 
        img = tifffile.imread(os.path.join(path_images, filename))/255.
        img_new = model_predict_batch(preds[i],
                                      count_erase= 15,
                                      radius=3)
        img_stardist =  tifffile.imread(os.path.join(path_baseline,filename)).astype(int)
        img_gt =  tifffile.imread(os.path.join(path_gt,filename)).astype(int)
        img_gt = remove_wrong_annotation(img_gt)

        precision_star, recall_star, F1_star, matched_pairs = calculate_precision_recall(img_stardist,img_gt)
        precision_seg, recall_seg, F1_seg, matched_pairs = calculate_precision_recall(img_new,img_gt)

        star_P.append(precision_star)
        star_R.append(recall_star)
        star_F1.append(F1_star)
        star_AJI.append(AJI(img_stardist,img_gt))
        star_DICE.append(DICE(img_stardist,img_gt))

        new_P.append(precision_seg)
        new_R.append(recall_seg)
        new_F1.append(F1_seg)
        new_AJI.append(AJI(img_new,img_gt))
        new_DICE.append(DICE(img_new,img_gt))
        precision_diff = np.mean(new_P) - np.mean(star_P)
        recall_diff = np.mean(new_R) - np.mean(star_R)

        t.set_description('precision diff:'+ str(np.round(precision_diff, 4)) +' || ' +'recall diff:'+ str(np.round(recall_diff, 4)))
        t.refresh()

table = BeautifulTable()

table.columns.header = ["new segmentation","stardist"]
table.rows.append([np.mean(np.array(new_P)),np.mean(np.array(star_P))])
table.rows.append([np.mean(np.array(new_R)),np.mean(np.array(star_R))])
table.rows.append([np.mean(np.array(new_F1)),np.mean(np.array(star_F1))])
table.rows.append([np.mean(np.array(new_AJI)),np.mean(np.array(star_AJI))])
table.rows.append([np.mean(np.array(new_DICE)),np.mean(np.array(star_DICE))])
table.rows.header = ["precision", "recall",'F1', "AJI", "DICE"]
# Out:
# precision diff:0.0711 || recall diff:0.233: 100%|██████████| 1185/1185 [09:15<00:00,  2.14it/s]

# %%
print(table)
# Out:
# +-----------+------------------+----------+
# |           | new segmentation | stardist |
# +-----------+------------------+----------+
# | precision |      0.904       |  0.833   |
# +-----------+------------------+----------+
# |  recall   |      0.808       |  0.575   |
# +-----------+------------------+----------+
# |    F1     |      0.825       |  0.654   |
# +-----------+------------------+----------+
# |    AJI    |      0.709       |  0.428   |
# +-----------+------------------+----------+
# |   DICE    |       0.82       |  0.574   |
# +-----------+------------------+----------+
